# %% [markdown]
# <a href="https://colab.research.google.com/github/Trapti04/python_learning/blob/Trapti04-patch-1/R1_Lab_External_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
## Reading a dataset from a csv file using pandas.
import pandas as pd
dfIris = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Iris_external.csv')
dfIris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
dfIris.columns
dfIris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
dfIris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
# 5                   5.4                  3.9  ...                  0.4  Iris-setosa
# 6                   4.6                  3.4  ...                  0.3  Iris-setosa
# 7                   5.0                  3.4  ...                  0.2  Iris-setosa
# 8                   4.4                  2.9  ...                  0.2  Iris-setosa
# 9                   4.9                  3.1  ...                  0.1  Iris-setosa
#
# [10 rows x 5 columns]

# %%
dfIris.tail(10)
# Out:
#      Sepal Length (in cm)  ...           Class
# 140                   6.7  ...  Iris-virginica
# 141                   6.9  ...  Iris-virginica
# 142                   5.8  ...  Iris-virginica
# 143                   6.8  ...  Iris-virginica
# 144                   6.7  ...  Iris-virginica
# 145                   6.7  ...  Iris-virginica
# 146                   6.3  ...  Iris-virginica
# 147                   6.5  ...  Iris-virginica
# 148                   6.2  ...  Iris-virginica
# 149                   5.9  ...  Iris-virginica
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Find the shape of the dataset

# %%
dfIris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
dfIris.index = dfIris['Sepal Length (in cm)']

# %%
dfIris.head(10)
# Out:
#                       Sepal Length (in cm)  ...        Class
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
# 4.7                                    4.7  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 4.4                                    4.4  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
dfIris.iloc[:, 2:3]
# Out:
#                       Petal length (in cm)
# Sepal Length (in cm)
# 5.1                                    1.4
# 4.9                                    1.4
# 4.7                                    1.3
# 4.6                                    1.5
# 5.0                                    1.4
# 5.4                                    1.7
# 4.6                                    1.4
# 5.0                                    1.5
# 4.4                                    1.4
# 4.9                                    1.5
# 5.4                                    1.5
# 4.8                                    1.6
# 4.8                                    1.4
# 4.3                                    1.1
# 5.8                                    1.2
# 5.7                                    1.5
# 5.4                                    1.3
# 5.1                                    1.4
# 5.7                                    1.7
# 5.1                                    1.5
# 5.4                                    1.7
# 5.1                                    1.5
# 4.6                                    1.0
# 5.1                                    1.7
# 4.8                                    1.9
# 5.0                                    1.6
# 5.0                                    1.6
# 5.2                                    1.5
# 5.2                                    1.4
# 4.7                                    1.6
# ...                                    ...
# 6.9                                    5.7
# 5.6                                    4.9
# 7.7                                    6.7
# 6.3                                    4.9
# 6.7                                    5.7
# 7.2                                    6.0
# 6.2                                    4.8
# 6.1                                    4.9
# 6.4                                    5.6
# 7.2                                    5.8
# 7.4                                    6.1
# 7.9                                    6.4
# 6.4                                    5.6
# 6.3                                    5.1
# 6.1                                    5.6
# 7.7                                    6.1
# 6.3                                    5.6
# 6.4                                    5.5
# 6.0                                    4.8
# 6.9                                    5.4
# 6.7                                    5.6
# 6.9                                    5.1
# 5.8                                    5.1
# 6.8                                    5.9
# 6.7                                    5.7
# 6.7                                    5.2
# 6.3                                    5.0
# 6.5                                    5.2
# 6.2                                    5.4
# 5.9                                    5.1
#
# [150 rows x 1 columns]

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
dfIris.iloc[0:10, 0:2]
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
dfIris[dfIris["Class"] == "Iris-setosa"]
# Out:
#                       Sepal Length (in cm)  ...        Class
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
# 4.7                                    4.7  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 4.4                                    4.4  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 4.8                                    4.8  ...  Iris-setosa
# 4.8                                    4.8  ...  Iris-setosa
# 4.3                                    4.3  ...  Iris-setosa
# 5.8                                    5.8  ...  Iris-setosa
# 5.7                                    5.7  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 5.7                                    5.7  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 4.8                                    4.8  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.2                                    5.2  ...  Iris-setosa
# 5.2                                    5.2  ...  Iris-setosa
# 4.7                                    4.7  ...  Iris-setosa
# 4.8                                    4.8  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 5.2                                    5.2  ...  Iris-setosa
# 5.5                                    5.5  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.5                                    5.5  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
# 4.4                                    4.4  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 4.5                                    4.5  ...  Iris-setosa
# 4.4                                    4.4  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 4.8                                    4.8  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.3                                    5.3  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
#
# [50 rows x 5 columns]

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
dfIris["SepalExtra"] = dfIris["Sepal Length (in cm)"] * dfIris["Sepal Width in (cm)"]

# %%
dfIris.head()
# Out:
#                       Sepal Length (in cm)  ...  SepalExtra
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...       17.85
# 4.9                                    4.9  ...       14.70
# 4.7                                    4.7  ...       15.04
# 4.6                                    4.6  ...       14.26
# 5.0                                    5.0  ...       18.00
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
dfIris.describe()
# Out:
#        Sepal Length (in cm)  ...  SepalExtra
# count            150.000000  ...  150.000000
# mean               5.843333  ...   17.806533
# std                0.828066  ...    3.368693
# min                4.300000  ...   10.000000
# 25%                5.100000  ...   15.645000
# 50%                5.800000  ...   17.660000
# 75%                6.400000  ...   20.325000
# max                7.900000  ...   30.020000
#
# [8 rows x 5 columns]

# %%
dfIris.mean()
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
dfIris.var()
# Out:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def print_num(num1, num2):
    print(num1, num2)

dfIris.iloc[4][0]   
    
print_num(dfIris.iloc[4][0] , dfIris.iloc[4][1] )
# Out:
# 5.0 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
dfIris.max(axis = 0, numeric_only= True) - dfIris.min(axis = 0,numeric_only= True)
# Out:
# Sepal Length (in cm)     3.60
# Sepal Width in (cm)      2.40
# Petal length (in cm)     5.90
# Petal width (in cm)      2.40
# SepalExtra              20.02
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
dfIris.sort_values("Petal width (in cm)")
# Out:
#                       Sepal Length (in cm)  ...  SepalExtra
# Sepal Length (in cm)                        ...
# 5.2                                    5.2  ...       21.32
# 4.3                                    4.3  ...       12.90
# 4.9                                    4.9  ...       15.19
# 4.9                                    4.9  ...       15.19
# 4.8                                    4.8  ...       14.40
# 4.9                                    4.9  ...       15.19
# 5.1                                    5.1  ...       17.85
# 5.2                                    5.2  ...       18.20
# 5.2                                    5.2  ...       17.68
# 4.7                                    4.7  ...       15.04
# 4.8                                    4.8  ...       14.88
# 5.5                                    5.5  ...       23.10
# 5.5                                    5.5  ...       19.25
# 4.4                                    4.4  ...       13.20
# 5.1                                    5.1  ...       17.34
# 4.4                                    4.4  ...       14.08
# 5.1                                    5.1  ...       19.38
# 4.6                                    4.6  ...       14.72
# 5.3                                    5.3  ...       19.61
# 5.0                                    5.0  ...       16.50
# 5.0                                    5.0  ...       15.00
# 4.8                                    4.8  ...       16.32
# 5.0                                    5.0  ...       16.00
# 4.6                                    4.6  ...       14.26
# 4.7                                    4.7  ...       15.04
# 5.0                                    5.0  ...       17.00
# 4.4                                    4.4  ...       12.76
# 5.4                                    5.4  ...       19.98
# 5.0                                    5.0  ...       18.00
# 4.8                                    4.8  ...       16.32
# ...                                    ...  ...         ...
# 6.4                                    6.4  ...       17.28
# 5.6                                    5.6  ...       15.68
# 7.7                                    7.7  ...       21.56
# 6.5                                    6.5  ...       19.50
# 5.7                                    5.7  ...       14.25
# 7.9                                    7.9  ...       30.02
# 6.5                                    6.5  ...       20.80
# 6.9                                    6.9  ...       21.39
# 7.1                                    7.1  ...       21.30
# 6.8                                    6.8  ...       20.40
# 7.6                                    7.6  ...       22.80
# 6.7                                    6.7  ...       22.11
# 6.4                                    6.4  ...       17.92
# 7.7                                    7.7  ...       29.26
# 6.4                                    6.4  ...       17.92
# 6.5                                    6.5  ...       19.50
# 6.9                                    6.9  ...       22.08
# 6.4                                    6.4  ...       20.48
# 6.2                                    6.2  ...       21.08
# 6.9                                    6.9  ...       21.39
# 6.8                                    6.8  ...       21.76
# 6.7                                    6.7  ...       20.10
# 7.7                                    7.7  ...       20.02
# 7.7                                    7.7  ...       23.10
# 6.3                                    6.3  ...       21.42
# 6.7                                    6.7  ...       20.77
# 5.8                                    5.8  ...       16.24
# 6.3                                    6.3  ...       20.79
# 6.7                                    6.7  ...       22.11
# 7.2                                    7.2  ...       25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
dfIris.drop(labels = "SepalExtra",axis = 1)
# Out:
#                       Sepal Length (in cm)  ...           Class
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...     Iris-setosa
# 4.9                                    4.9  ...     Iris-setosa
# 4.7                                    4.7  ...     Iris-setosa
# 4.6                                    4.6  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 4.6                                    4.6  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 4.4                                    4.4  ...     Iris-setosa
# 4.9                                    4.9  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 4.8                                    4.8  ...     Iris-setosa
# 4.8                                    4.8  ...     Iris-setosa
# 4.3                                    4.3  ...     Iris-setosa
# 5.8                                    5.8  ...     Iris-setosa
# 5.7                                    5.7  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 5.7                                    5.7  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 4.6                                    4.6  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 4.8                                    4.8  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 5.2                                    5.2  ...     Iris-setosa
# 5.2                                    5.2  ...     Iris-setosa
# 4.7                                    4.7  ...     Iris-setosa
# ...                                    ...  ...             ...
# 6.9                                    6.9  ...  Iris-virginica
# 5.6                                    5.6  ...  Iris-virginica
# 7.7                                    7.7  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 7.2                                    7.2  ...  Iris-virginica
# 6.2                                    6.2  ...  Iris-virginica
# 6.1                                    6.1  ...  Iris-virginica
# 6.4                                    6.4  ...  Iris-virginica
# 7.2                                    7.2  ...  Iris-virginica
# 7.4                                    7.4  ...  Iris-virginica
# 7.9                                    7.9  ...  Iris-virginica
# 6.4                                    6.4  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.1                                    6.1  ...  Iris-virginica
# 7.7                                    7.7  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.4                                    6.4  ...  Iris-virginica
# 6.0                                    6.0  ...  Iris-virginica
# 6.9                                    6.9  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 6.9                                    6.9  ...  Iris-virginica
# 5.8                                    5.8  ...  Iris-virginica
# 6.8                                    6.8  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.5                                    6.5  ...  Iris-virginica
# 6.2                                    6.2  ...  Iris-virginica
# 5.9                                    5.9  ...  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset =  dfIris.iloc[:10, :3]
IrisSubset
# Out:
#                       Sepal Length (in cm)  ...  Petal length (in cm)
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...                   1.4
# 4.9                                    4.9  ...                   1.4
# 4.7                                    4.7  ...                   1.3
# 4.6                                    4.6  ...                   1.5
# 5.0                                    5.0  ...                   1.4
# 5.4                                    5.4  ...                   1.7
# 4.6                                    4.6  ...                   1.4
# 5.0                                    5.0  ...                   1.5
# 4.4                                    4.4  ...                   1.4
# 4.9                                    4.9  ...                   1.5
#
# [10 rows x 3 columns]

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
dfHRdata = pd.read_csv('/content/drive/My Drive/Colab Notebooks/HR_external.txt', sep ='\t')
dfHRdata.head()
# Out:
#   Individual  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0        Ind1       Yes  ...                        0                     5
# 1        Ind2        No  ...                        1                     7
# 2        Ind3       Yes  ...                        0                     0
# 3        Ind4        No  ...                        3                     0
# 4        Ind5        No  ...                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
dfHRdata.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
dfHRdata.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
dfHRdata.iloc[:, 2:10]
# Out:
#       Age  BusinessTravel  DailyRate  ...  Education  EducationField  EmployeeCount
# 0      41               1       1102  ...          2               1              1
# 1      49               2        279  ...          1               1              1
# 2      37               1       1373  ...          2               6              1
# 3      33               2       1392  ...          4               1              1
# 4      27               1        591  ...          1               2              1
# 5      32               2       1005  ...          2               1              1
# 6      59               1       1324  ...          3               2              1
# 7      30               1       1358  ...          1               1              1
# 8      38               2        216  ...          3               1              1
# 9      36               1       1299  ...          3               2              1
# 10     35               1        809  ...          3               2              1
# 11     29               1        153  ...          2               1              1
# 12     31               1        670  ...          1               1              1
# 13     34               1       1346  ...          2               2              1
# 14     28               1        103  ...          3               1              1
# 15     29               1       1389  ...          4               1              1
# 16     32               1        334  ...          2               1              1
# 17     22               3       1123  ...          2               2              1
# 18     53               1       1219  ...          4               1              1
# 19     38               1        371  ...          3               1              1
# 20     24               3        673  ...          2               6              1
# 21     36               1       1218  ...          4               1              1
# 22     34               1        419  ...          4               1              1
# 23     21               1        391  ...          2               1              1
# 24     34               1        699  ...          1               2              1
# 25     53               1       1282  ...          3               6              1
# 26     32               2       1125  ...          1               1              1
# 27     42               1        691  ...          4               3              1
# 28     44               1        477  ...          4               2              1
# 29     46               1        705  ...          4               3              1
# ...   ...             ...        ...  ...        ...             ...            ...
# 1440   36               2        688  ...          2               1              1
# 1441   56               3        667  ...          4               1              1
# 1442   29               1       1092  ...          4               2              1
# 1443   42               1        300  ...          3               1              1
# 1444   56               1        310  ...          2               4              1
# 1445   41               1        582  ...          4               1              1
# 1446   34               1        704  ...          3               3              1
# 1447   36               3        301  ...          4               3              1
# 1448   41               1        930  ...          3               1              1
# 1449   32               1        529  ...          3               4              1
# 1450   35               1       1146  ...          4               1              1
# 1451   38               1        345  ...          2               1              1
# 1452   50               2        878  ...          4               1              1
# 1453   36               1       1120  ...          4               3              1
# 1454   45               1        374  ...          3               1              1
# 1455   40               1       1322  ...          4               1              1
# 1456   35               2       1199  ...          4               1              1
# 1457   40               1       1194  ...          4               2              1
# 1458   35               1        287  ...          4               1              1
# 1459   29               1       1378  ...          2               6              1
# 1460   29               1        468  ...          4               2              1
# 1461   50               1        410  ...          3               3              1
# 1462   39               1        722  ...          1               3              1
# 1463   31               3        325  ...          3               2              1
# 1464   26               1       1167  ...          3               6              1
# 1465   36               2        884  ...          2               2              1
# 1466   39               1        613  ...          1               2              1
# 1467   27               1        155  ...          3               1              1
# 1468   49               2       1023  ...          3               2              1
# 1469   34               1        628  ...          3               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
gender_type1 = dfHRdata.loc[lambda dfHRdata: dfHRdata["Gender"] == 1]
print(gender_type1.shape[0])
# Out:
# 882

# %%
print(dfHRdata.shape[0] - gender_type1.shape[0])
# Out:
# 588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
dfHRdata["Age"].quantile(q = .75)-dfHRdata["Age"].quantile(q = .25)
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
dfHRdata["DailyRate"].mean()
# Out:
# 802.4857142857143

# %%
dfHRdata["DailyRate"].median()
# Out:
# 802.0

# %%
dfHRdata["DailyRate"].var()
# Out:
# 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.countplot(x="Attrition" , data = dfHRdata)

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
plt.plot(dfHRdata.TotalWorkingYears)
